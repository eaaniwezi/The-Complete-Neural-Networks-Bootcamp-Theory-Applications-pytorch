# %%
import torch
import os
import torch.nn as nn
import numpy as np
from torch.nn.utils import clip_grad_norm

# %%
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1
            
    def __len__(self):
        return len(self.word2idx)

# %%
class TextProcess(object):
    
    def __init__(self):
        self.dictionary = Dictionary()

    def get_data(self, path, batch_size=20):
        with open(path, 'r') as f:
            tokens = 0
            for line in f:
                words = line.split() + ['<eos>']
                tokens += len(words)
                for word in words: 
                    self.dictionary.add_word(word)  
        #Create a 1-D tensor that contains the index of all the words in the file
        rep_tensor = torch.LongTensor(tokens)
        index = 0
        with open(path, 'r') as f:
            for line in f:
                words = line.split() + ['<eos>']
                for word in words:
                    rep_tensor[index] = self.dictionary.word2idx[word]
                    index += 1
        #Find out how many batches we need            
        num_batches = rep_tensor.shape[0] // batch_size     
        #Remove the remainder (Filter out the ones that don't fit)
        rep_tensor = rep_tensor[:num_batches*batch_size]
        # return (batch_size,num_batches)
        rep_tensor = rep_tensor.view(batch_size, -1)
        return rep_tensor

# %%
embed_size = 128    #Input features to the LSTM
hidden_size = 1024  #Number of LSTM units
num_layers = 1
num_epochs = 20
batch_size = 20
timesteps = 30
learning_rate = 0.002

# %%
corpus = TextProcess()

# %%
rep_tensor = corpus.get_data('alice.txt', batch_size)

# %%
#rep_tensor is the tensor that contains the index of all the words. Each row contains 1659 words by default 
print(rep_tensor.shape)
# Out:
# torch.Size([20, 1484])

# %%
vocab_size = len(corpus.dictionary)
print(vocab_size)
# Out:
# 5290

# %%
num_batches = rep_tensor.shape[1] // timesteps
print(num_batches)
# Out:
# 49

# %%
class TextGenerator(nn.Module):
    
    def __init__(self, vocab_size, embed_size, hidden_size, num_layers):
        super(TextGenerator, self).__init__()
        self.embed = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)

    def forward(self, x, h):
        # Perform Word Embedding 
        x = self.embed(x)
        #Reshape the input tensor
        #x = x.view(batch_size,timesteps,embed_size)
        out, (h, c) = self.lstm(x, h)
        # Reshape the output from (samples,timesteps,output_features) to a shape appropriate for the FC layer 
        # (batch_size*timesteps, hidden_size)
        out = out.reshape(out.size(0)*out.size(1), out.size(2))
        # Decode hidden states of all time steps
        out = self.linear(out)
        return out, (h, c)

# %%
model = TextGenerator(vocab_size, embed_size, hidden_size, num_layers)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def detach(states):
    """
If we have a tensor z,'z.detach()' returns a tensor that shares the same storage
as 'z', but with the computation history forgotten. It doesn't know anything
about how it was computed. In other words, we have broken the tensor z away from its past history
Here, we want to perform truncated Backpropagation
TBPTT splits the 1,000-long sequence into 50 sequences (say) each of length 20 and treats each sequence of length 20 as 
a separate training case. This is a sensible approach that can work well in practice, but it is blind to temporal 
dependencies that span more than 20 timesteps.
    """
    return [state.detach() for state in states]

# %%
for epoch in range(num_epochs):
    # Set initial hidden and cell states
    states = (torch.zeros(num_layers, batch_size, hidden_size),
              torch.zeros(num_layers, batch_size, hidden_size))

    for i in range(0, rep_tensor.size(1) - timesteps, timesteps):
        # Get mini-batch inputs and targets
        inputs = rep_tensor[:, i:i+timesteps]  
        targets = rep_tensor[:, (i+1):(i+1)+timesteps]
        
        outputs,_ = model(inputs, states)
        loss = loss_fn(outputs, targets.reshape(-1))

        model.zero_grad()
        loss.backward()
        #Perform Gradient Clipping. clip_value (float or int) is the maximum allowed value of the gradients 
        #The gradients are clipped in the range [-clip_value, clip_value]. This is to prevent the exploding gradient problem
        clip_grad_norm(model.parameters(), 0.5)
        optimizer.step()
              
        step = (i+1) // timesteps
        if step % 100 == 0:
            print ('Epoch [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, loss.item()))
# Out:
# C:\Users\eaani\AppData\Local\Temp\ipykernel_24104\1921955779.py:18: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   clip_grad_norm(model.parameters(), 0.5)
# Epoch [1/20], Loss: 8.5703
# Epoch [2/20], Loss: 6.0203
# Epoch [3/20], Loss: 5.3118
# Epoch [4/20], Loss: 4.7399
# Epoch [5/20], Loss: 4.1377
# Epoch [6/20], Loss: 3.6836
# Epoch [7/20], Loss: 3.2746
# Epoch [8/20], Loss: 2.8751
# Epoch [9/20], Loss: 2.4605
# Epoch [10/20], Loss: 2.0977
# Epoch [11/20], Loss: 1.8087
# Epoch [12/20], Loss: 1.4975
# Epoch [13/20], Loss: 1.2684
# Epoch [14/20], Loss: 0.9861
# Epoch [15/20], Loss: 0.7220
# Epoch [16/20], Loss: 0.4507
# Epoch [17/20], Loss: 0.3480
# Epoch [18/20], Loss: 0.1883
# Epoch [19/20], Loss: 0.1225
# Epoch [20/20], Loss: 0.0821

# %%
# Test the model
with torch.no_grad():
    with open('results.txt', 'w') as f:
        # Set intial hidden ane cell states
        state = (torch.zeros(num_layers, 1, hidden_size),
                 torch.zeros(num_layers, 1, hidden_size))
        # Select one word id randomly and convert it to shape (1,1)
        input = torch.randint(0,vocab_size, (1,)).long().unsqueeze(1)

        for i in range(500):
            output, _ = model(input, state)
            print(output.shape)
            # Sample a word id from the exponential of the output 
            prob = output.exp()
            word_id = torch.multinomial(prob, num_samples=1).item()
            print(word_id)
            # Replace the input with sampled word id for the next time step
            input.fill_(word_id)

            # Write the results to file
            word = corpus.dictionary.idx2word[word_id]
            word = '\n' if word == '<eos>' else word + ' '
            f.write(word)
            
            if (i+1) % 100 == 0:
                print('Sampled [{}/{}] words and save to {}'.format(i+1, 500, 'results.txt'))
# Out:
# torch.Size([1, 5290])
# 451
# torch.Size([1, 5290])
# 73
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 22
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 150
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4772
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 2986
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 285
# torch.Size([1, 5290])
# 2546
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1284
# torch.Size([1, 5290])
# 557
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 4619
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 3403
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 980
# torch.Size([1, 5290])
# 4789
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1117
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 3187
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 35
# torch.Size([1, 5290])
# 2678
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 426
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 776
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 3187
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 2593
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2812
# torch.Size([1, 5290])
# 3091
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 2593
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 1233
# torch.Size([1, 5290])
# 137
# torch.Size([1, 5290])
# 485
# torch.Size([1, 5290])
# 25
# torch.Size([1, 5290])
# 1595
# torch.Size([1, 5290])
# 1672
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 22
# torch.Size([1, 5290])
# 375
# torch.Size([1, 5290])
# 2010
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 285
# torch.Size([1, 5290])
# 1001
# torch.Size([1, 5290])
# 41
# torch.Size([1, 5290])
# 42
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1862
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 265
# torch.Size([1, 5290])
# 787
# torch.Size([1, 5290])
# 1001
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 4924
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 1609
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 285
# torch.Size([1, 5290])
# 1001
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 313
# torch.Size([1, 5290])
# 162
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 463
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 4204
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 4167
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2042
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 129
# torch.Size([1, 5290])
# 1164
# torch.Size([1, 5290])
# 1622
# torch.Size([1, 5290])
# 13
# Sampled [100/500] words and save to results.txt
# torch.Size([1, 5290])
# 1331
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 165
# torch.Size([1, 5290])
# 1231
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 898
# torch.Size([1, 5290])
# 781
# torch.Size([1, 5290])
# 151
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 35
# torch.Size([1, 5290])
# 2678
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 937
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 251
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 2430
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 43
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 253
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1552
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 798
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4772
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 505
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 982
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 165
# torch.Size([1, 5290])
# 2812
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4772
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1102
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 43
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 207
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 129
# torch.Size([1, 5290])
# 841
# torch.Size([1, 5290])
# 41
# torch.Size([1, 5290])
# 42
# torch.Size([1, 5290])
# 173
# torch.Size([1, 5290])
# 945
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1552
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 1617
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3061
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 2183
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3830
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 1040
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 129
# torch.Size([1, 5290])
# 3131
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 555
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 427
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1667
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 35
# torch.Size([1, 5290])
# 2678
# torch.Size([1, 5290])
# 22
# torch.Size([1, 5290])
# 375
# torch.Size([1, 5290])
# 18
# torch.Size([1, 5290])
# 2958
# torch.Size([1, 5290])
# 110
# torch.Size([1, 5290])
# 251
# Sampled [200/500] words and save to results.txt
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 898
# torch.Size([1, 5290])
# 781
# torch.Size([1, 5290])
# 668
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 4369
# torch.Size([1, 5290])
# 960
# torch.Size([1, 5290])
# 3702
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1457
# torch.Size([1, 5290])
# 3607
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 193
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3832
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 915
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3197
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 193
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 4185
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 996
# torch.Size([1, 5290])
# 1821
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 116
# torch.Size([1, 5290])
# 3353
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 344
# torch.Size([1, 5290])
# 250
# torch.Size([1, 5290])
# 251
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4772
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2974
# torch.Size([1, 5290])
# 73
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 427
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1862
# torch.Size([1, 5290])
# 320
# torch.Size([1, 5290])
# 74
# torch.Size([1, 5290])
# 344
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3225
# torch.Size([1, 5290])
# 173
# torch.Size([1, 5290])
# 4451
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 160
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 362
# torch.Size([1, 5290])
# 389
# torch.Size([1, 5290])
# 483
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 980
# torch.Size([1, 5290])
# 4789
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 2059
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 427
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1452
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 269
# torch.Size([1, 5290])
# 30
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 253
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3289
# torch.Size([1, 5290])
# 1511
# torch.Size([1, 5290])
# 251
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 160
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 22
# torch.Size([1, 5290])
# 375
# Sampled [300/500] words and save to results.txt
# torch.Size([1, 5290])
# 4244
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 2756
# torch.Size([1, 5290])
# 3607
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1552
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 1617
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 411
# torch.Size([1, 5290])
# 1302
# torch.Size([1, 5290])
# 2471
# torch.Size([1, 5290])
# 2228
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 305
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 98
# torch.Size([1, 5290])
# 3674
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 96
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 4167
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2204
# torch.Size([1, 5290])
# 930
# torch.Size([1, 5290])
# 1533
# torch.Size([1, 5290])
# 5057
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2974
# torch.Size([1, 5290])
# 73
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5239
# torch.Size([1, 5290])
# 92
# torch.Size([1, 5290])
# 173
# torch.Size([1, 5290])
# 945
# torch.Size([1, 5290])
# 777
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 671
# torch.Size([1, 5290])
# 3261
# torch.Size([1, 5290])
# 71
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1457
# torch.Size([1, 5290])
# 3607
# torch.Size([1, 5290])
# 110
# torch.Size([1, 5290])
# 2423
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 505
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 300
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3775
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 1351
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 4185
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 843
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3027
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 668
# torch.Size([1, 5290])
# 42
# torch.Size([1, 5290])
# 238
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 4204
# torch.Size([1, 5290])
# 42
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1862
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 600
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 615
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 4648
# torch.Size([1, 5290])
# 73
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 518
# torch.Size([1, 5290])
# 4738
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 150
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 46
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 252
# Sampled [400/500] words and save to results.txt
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3475
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3832
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 4619
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 530
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3779
# torch.Size([1, 5290])
# 98
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 463
# torch.Size([1, 5290])
# 117
# torch.Size([1, 5290])
# 60
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1637
# torch.Size([1, 5290])
# 1638
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 980
# torch.Size([1, 5290])
# 4789
# torch.Size([1, 5290])
# 5027
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 898
# torch.Size([1, 5290])
# 781
# torch.Size([1, 5290])
# 155
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 209
# torch.Size([1, 5290])
# 18
# torch.Size([1, 5290])
# 329
# torch.Size([1, 5290])
# 4755
# torch.Size([1, 5290])
# 5211
# torch.Size([1, 5290])
# 1247
# torch.Size([1, 5290])
# 898
# torch.Size([1, 5290])
# 781
# torch.Size([1, 5290])
# 72
# torch.Size([1, 5290])
# 73
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 317
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 530
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 3187
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 713
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 2584
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 4619
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 3077
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 129
# torch.Size([1, 5290])
# 671
# torch.Size([1, 5290])
# 3261
# torch.Size([1, 5290])
# 189
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 253
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 134
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 43
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5234
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2665
# torch.Size([1, 5290])
# 4485
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1585
# torch.Size([1, 5290])
# 2710
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 4185
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 843
# torch.Size([1, 5290])
# 980
# torch.Size([1, 5290])
# 4789
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 1617
# torch.Size([1, 5290])
# 1196
# torch.Size([1, 5290])
# 2028
# torch.Size([1, 5290])
# 11
# Sampled [500/500] words and save to results.txt
